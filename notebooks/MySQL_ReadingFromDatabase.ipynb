# %%
import getpass
import sqlalchemy
import pandas as pd

# %% [markdown]
# ## Database Connection

# %% [markdown]
# You'll see the username and password in the whatsapp group.

# %%
user = getpass.getpass()
# Out:
#  ····

# %%
pwd = getpass.getpass()
# Out:
#  ·······························

# %%
DB_URIfix='mysql+pymysql://'+user+':'+pwd+'@35.197.16.55/wiki'+'?charset=utf8mb4'
engine = sqlalchemy.create_engine(DB_URIfix)

# %% [markdown]
# ### Reading from database

# %%
SQL_example1 = """
SELECT *
FROM wiki.Clickstream 
WHERE `From` = 'Know_Nothing';
"""

df1 = pd.read_sql(SQL_example1, engine)
df1
# Out:
#     Snapshot          From                                                 To  \
# 0     202001  Know_Nothing                                   Thaddeus_Stevens
# 1     202001  Know_Nothing         Constitutional_Union_Party_(United_States)
# 2     202001  Know_Nothing  1854_and_1855_United_States_House_of_Represent...
# 3     202001  Know_Nothing                                   Anti-Catholicism
# 4     202001  Know_Nothing                         Anthony_Kennedy_(Maryland)
# ..       ...           ...                                                ...
# 93    202001  Know_Nothing                                   J._Neely_Johnson
# 94    202001  Know_Nothing                               American_nationalism
# 95    202001  Know_Nothing                             Noah_Gordon_(novelist)
# 96    202001  Know_Nothing                          Flag_of_the_United_States
# 97    202001  Know_Nothing           1852_United_States_presidential_election
#
#    RelationType  Count
# 0          link    125
# 1          link   1980
# 2          link    137
# 3          link    268
# 4          link     95
# ..          ...    ...
# 93         link     41
# 94         link     89
# 95         link     28
# 96        other     34
# 97         link     14
#
# [98 rows x 5 columns]

# %%
SQL_example2 = """
SELECT * 
FROM wiki.Clickstream 
WHERE `To` = 'Thaddeus_Stevens' ;
"""

df2 = pd.read_sql(SQL_example2, engine)
df2
# Out:
#     Snapshot                                       From                To  \
# 0     202001              Lost_Cause_of_the_Confederacy  Thaddeus_Stevens
# 1     202001                             other-external  Thaddeus_Stevens
# 2     202001                                   Thaddeus  Thaddeus_Stevens
# 3     202001                         American_Civil_War  Thaddeus_Stevens
# 4     202001                            Roscoe_Conkling  Thaddeus_Stevens
# ..       ...                                        ...               ...
# 64    202001              United_States_Capitol_rotunda  Thaddeus_Stevens
# 65    202001  Pennsylvania's_8th_congressional_district  Thaddeus_Stevens
# 66    202001                          Danville,_Vermont  Thaddeus_Stevens
# 67    202001                         Anti-Masonic_Party  Thaddeus_Stevens
# 68    202001                          Tennessee_Johnson  Thaddeus_Stevens
#
#    RelationType  Count
# 0          link     21
# 1      external    583
# 2          link     30
# 3          link     15
# 4          link     84
# ..          ...    ...
# 64         link     95
# 65         link     11
# 66         link     12
# 67         link    103
# 68         link     15
#
# [69 rows x 5 columns]
